# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys

# Ensure the clt package is discoverable
project_dir = os.path.abspath('..')
if project_dir not in sys.path:
    sys.path.insert(0, project_dir)

from clt.config.clt_config import TrainingConfig
from clt.training.data.activation_store_factory import create_activation_store

# %%
device = 'cuda'
cfg = TrainingConfig(
    learning_rate=1e-4,
    training_steps=5000,
    train_batch_size_tokens=256,
    precision='fp32',
    debug_anomaly=True,
    activation_source='local_manifest',
    activation_dtype='float32',
    activation_path='/uufs/chpc.utah.edu/common/home/u1472283/scr/crosslayer-coding/data/activations/allenai/OLMo-2-0425-1B-Instruct/olmo-mix-1124_train_float32_1000000toks_1000chunks',
)

store = create_activation_store(
    training_config=cfg,
    clt_config=None,
    device=device,
    rank=0,
    world_size=1,
    start_time=None,
    shard_data=True
)
store
# Out:
# INFO:clt.training.data.activation_store_factory:Rank 0: Using LocalActivationStore (reading local manifest/chunks).
# INFO:clt.training.data.local_activation_store:Manifest loaded (3-field format) from /scratch/general/vast/u1472283/crosslayer-coding/data/activations/allenai/OLMo-2-0425-1B-Instruct/olmo-mix-1124_train_float32_1000000toks_1000chunks/index.bin (76 chunks). Expanding to per-row entries.
# INFO:clt.training.data.local_activation_store:Expanding manifest: total rows = 1011572
# WARNING:clt.training.data.manifest_activation_store:'chunk_tokens' in metadata (1000) differs from median chunk size in manifest (11166) by more than 10% – treating it as a threshold and using the manifest value instead.
# INFO:clt.training.data.local_activation_store:Normalization stats loaded from /scratch/general/vast/u1472283/crosslayer-coding/data/activations/allenai/OLMo-2-0425-1B-Instruct/olmo-mix-1124_train_float32_1000000toks_1000chunks/norm_stats.json.
# ...
